# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
data = pd.Series([0.25,0.5,0.75,1])

# %%
data
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# dtype: float64

# %%
data
# Out:
# 0.75

# %%
'''
create a pandas series of even numbers between 1 to 10

'''
# Out:
# ' \ncreate a pandas series of even numbers between 1 to 10\n\n'

# %%
even_list =[i for i in range(100) if i%2 == 0]

# %%
pd.Series(even_list)
# Out:
# 0      0
# 1      2
# 2      4
# 3      6
# 4      8
# 5     10
# 6     12
# 7     14
# 8     16
# 9     18
# 10    20
# 11    22
# 12    24
# 13    26
# 14    28
# 15    30
# 16    32
# 17    34
# 18    36
# 19    38
# 20    40
# 21    42
# 22    44
# 23    46
# 24    48
# 25    50
# 26    52
# 27    54
# 28    56
# 29    58
# 30    60
# 31    62
# 32    64
# 33    66
# 34    68
# 35    70
# 36    72
# 37    74
# 38    76
# 39    78
# 40    80
# 41    82
# 42    84
# 43    86
# 44    88
# 45    90
# 46    92
# 47    94
# 48    96
# 49    98
# dtype: int64

# %%
data=pd.Series([]),index=['a','b','c','d'])
# Out:
#   File "<ipython-input-36-2e42e296a705>", line 1
#     data=pd.Series([]),index=['a','b','c','d'])
#                                               ^
# SyntaxError: unmatched ')'

# %%
import numpy as np

a = np.random.randint(0,10,size=(6))

# %%
a
# Out:
# array([9, 3, 0, 2, 7, 5])

# %%
pd.Series(a,index=[1,2,3,'a','b','c'])
# Out:
# 1    9
# 2    3
# 3    0
# a    2
# b    7
# c    5
# dtype: int64

# %%
population = {'AP':1000,'TS':5000,'KA':4000,'TN':1500}

ser = pd.Series(population)

# %%
ser['TN']
# Out:
# 1500

# %%
ser['TS']
# Out:
# 5000

# %%
ser[['TN','TS']]
# Out:
# TN    1500
# TS    5000
# dtype: int64
