# %%
cityname = 'hyderabad'

print(f'i am leaving in {cityname}')
# Out:
# i am leaving in hyderabad

# %%
l = ['dhoni','keran','lina','dog',]

print(f'my list is{l}')
# Out:
# my list is['dhoni', 'keran', 'lina', 'dog']

# %% [markdown]
# For Loop

# %%
l1 = ['manikant','ajay','ravi','kiran']

# %%
for i in l1:
  print(i)
# Out:
# manikant
# ajay
# ravi
# kiran

# %%
l1 = ['22','45','74','58']

# %%
for i in l1:
  print(i)
# Out:
# 22
# 45
# 74
# 58

# %%
l1= [33,45,56,'word','king']

for i in l1:
  print(f'my elemente in the list is {i}')
# Out:
# my elemente in the list is33
# my elemente in the list is45
# my elemente in the list is56
# my elemente in the list isword
# my elemente in the list isking

# %%
l1 = [2,4,6,8,10]

for i in  l1:
  print(f'{i+1}')
# Out:
# 3
# 5
# 7
# 9
# 11

# %%
'''
1.c reate a list of names and print thnamesose
2. create a list os 3 numbers  and multiply with 3 and add with l
3.create a list on 5 odd numbers divide with 2
'''

# %%
s1 = "ajay"
s2 = "kiran"

# %%
# for loop for combine words into a sentence

l1 = {"dog","kills","a","cat"}

sentence = ""
for i in l1:
  sentence = sentence + " " + i
  print(sentence)
# Out:
#  dog
#  dog kills
#  dog kills a
#  dog kills a cat

# %%
s1 = "laksmam"
s2 = "yellow"
s3 = "pink"

print(s1+" "+s2+ " " +s3)
# Out:
# laksmam yellow pink

# %%
#changing items in the list

# %%
 createa list of 1 to 100

# %%
l1 = [i for i in range(1,100)]

even = []
odd  = []

for i in l1:
 if i%2==0:
   even.append(i)
 if i%2 !=0:
   odd.append(i)

# %%
multiply = []
for j in l1:
  if j & 3 == 0:
    multiply.append(j)

# %%
thislist1 = ["apple","banana","cherry"]
thislist2 = ["orange","kiwi","melon","mango"]

thislist1.extend(thislist2)

# %%
thislist1
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango']

# %%
thislist = ["apple","banana","cherry","orange","kiwi","melon","mango"]

# remove cherry from the list using indexing and extend

# %%
l1 = thislist[:2]
l2 = thislist[3:]

# %%
l2
# Out:
# ['orange', 'kiwi', 'melon', 'mango']

# %%
l1
# Out:
# ['apple', 'banana']

# %%
l1.extend(l2)

# %%
l1
# Out:
# ['apple', 'banana', 'orange', 'kiwi', 'melon', 'mango']

# %%
thislist = ["apple","banana","cherry","orange","kiwi","melon","mango"]
thislist.remove('cherry')

# %%
thislist
# Out:
# ['apple', 'banana', 'orange', 'kiwi', 'melon', 'mango']

# %%
thislist = ["apple","banana","cherry","orange","kiwi","melon","mango"]
thislist.pop(2)
# Out:
# 'cherry'

# %%
thislist
# Out:
# ['apple', 'banana', 'orange', 'kiwi', 'melon', 'mango']

# %%
#looping throught the list

# %%
thislist = ["apple","banana","cherry","orange","kiwi","melon","mango"]
for i in thislist:
  print(i)
# Out:
# apple
# banana
# cherry
# orange
# kiwi
# melon
# mango

# %%
for i in range(0,len(thislist)):
 print(thislist[i])
# Out:
# apple
# banana
# cherry
# orange
# kiwi
# melon
# mango

# %%
i = 0#1
while (i<len(thislist)):#2
  print(thislist[i])
  i = i+1#3
# Out:
# apple
# banana
# cherry
# orange
# kiwi
# melon
# mango

# %%
[print(x) for x in thislist]
# Out:
# apple
# banana
# cherry
# orange
# kiwi
# melon
# mango
# [None, None, None, None, None, None, None]

# %%
thislist = ["apple","banana","cherry","orange","kiwi","melon","mango"]
newlist = []

###
#TODO : APPEND element to the newlist of charcter a is present in the word
###

# %%
for i in thislist:
 if 'a' in i:
   newlist.append(i)
print(newlist)
# Out:
# ['apple', 'banana', 'orange', 'mango']

# %%
newlist=[x for x in thislist if 'a' in x]#SHORTCUT

# %%
newlist
# Out:
# ['apple', 'banana', 'orange', 'mango']

# %%
## Sorting

# %%
thislist = [100,50,65,82,23]
thislist.sort()

# %%
thislist
# Out:
# [23, 50, 65, 82, 100]

# %%
thislist.sort(reverse = True)

# %%
thislist
# Out:
# [100, 82, 65, 50, 23]

# %%
# crete a function that calculates n-50 and check it this is less that zero you have to multply with -1

# %%
def func1(n):
  i = n-50
  if i<0:
    i*=-1
  return i

# %%
func1(10)
# Out:
# 40

# %%
thislist = [100,50,65,82,23]
thislist.sort(key=func1)

# %%
thislist
# Out:
# [50, 65, 23, 82, 100]

# %%
'''
[50,0,15,32,27]
[0,1,2,3,4]
shorted position [1,2,3,4,0]
'''

# %%
thislist = [100,50,65,82,23]
newlist=[]
for i in l1:
  i = i-50
  if i< 0:
    i *=-1
    newlist.append(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-094a6e8d0294> in <cell line: 3>()
#       2 newlist=[]
#       3 for i in l1:
# ----> 4   i = i-50
#       5   if i< 0:
#       6     i *=-1
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'
