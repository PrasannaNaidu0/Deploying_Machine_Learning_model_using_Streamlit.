# %%
'''

python - object oriented programming

# %%
class Book : #class Noteoftheclass

  #intialization - __init__

  '''
  varibles that are used in different methods are intializaed
  in the __init__ method

  '''
  def __init__(title,quantity,author,price):
   self.title = title
   self.quantity = quantity
   self.author = author
   self.price = price


  def printtitle(self):
    print(self.title)
  def printrevenue(self):
    print (self.price*self.quantity)


  def __repr__(self):#used for print statement
   return f"Book : {self.title}, quantity : {self.quantity}, author : {self.author}, price : {self.price}"

# %%
Book("Moon light",10,"willams",150) #classnema(intializations)
book.printtitle()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-535b6bd5596d> in <cell line: 1>()
# ----> 1 Book("Moon light",10,"willams",150) #classnema(intializations)
#       2 book.printtitle()
#
# TypeError: Book.__init__() takes 4 positional arguments but 5 were given

# %%
book.printrevenue()

# %%
Book("Moon light",10,"willams",150) #classnema(intializations)
Book("Moon light 2",10,"willams",150) #classnema(intializations)
Book("Moon light 3",10,"willams",150) #classnema(intializations)

# %%
print(book1)

# %% [markdown]
# #Encapsulations

# %%
class Book : #class Noteoftheclass

  #intialization - __init__

  '''
  varibles that are used in different methods are intializaed
  in the __init__ method

  '''
  def __init__(title,quantity,author,price):
   self.title = title
   self.quantity = quantity
   self.author = author
   self.price = price
   self .__discount = 0.15

 ## setter method - modify the variable
  def set_discount(self,discount):
   self.__discount = discount

## getter methodes
  def get_price(self):
     return self.price

  def printtitle(self):
    print(self.title)
  def printrevenue(self):
    print (self.price*self.quantity)


  def __repr__(self):#used for print statement
   return f"Book : {self.title}, quantity : {self.quantity}, author : {self.author}, price : {self.price}"

# %%
##getter and setter methods

book = Book("Tow states",1,"Chetan Bhagath",200)
book.set__discount(0.2)
book.get_price()

# %%
'''

Super market
(vegetables,fruits,choclates) quantity,price,discounts



'''

# %% [markdown]
# #Inheritance

# %%
'''
Ability of the class to inherit methods or properties from another class


Class 1 - methods - parent class
Class 2 - use those methods defined in class 2 - child class

'''

# %%
# PARENT CLASS

class book:
  def __init__(title,quantity,author,price):
   self.title = title
   self.quantity = quantity
   self.author = author
   self.price = price

  def set_discount(self,discount):
    self.__discount= discount

  def get_price(self):
    return self.__price*(1-self.__discount)



  def __repr__(self):#used for print statement
    return f"Book : {self.title}, quantity : {self.quantity}, author : {self.author}, price : {self.price}"
