# %% [markdown]
#  **Python** **Class** **1**

# %%
shoes = 5
shirts = 7

print (f'I bought {shoes} shoes and {shirts} shirts')
# Out:
# I bought 5 shoes and 7 shirts

# %% [markdown]
# **Arithemtic** **Operations**

# %%
print( 100/50)
# Out:
# 2.0

# %%
print (100-50)
# Out:
# 50

# %%
print ( 5*30)
# Out:
# 150

# %%
apple = 5
orange = 4
bannas = 6

print (f'i bought {apple} apple and {orange} oranges and {bannas} bannas')
# Out:
# i bought 5 apple and 4 oranges and 6 bannas

# %% [markdown]
# **List** **In** **Python**

# %%
'''
List is a type  varlable that handle multiple imput
'''

l1 = [1,3,4,6,7,89,90]
l2 = ['ajay','bob','king','queen']
l3 = [1,3,'ajay',6,7,'queen']

# %%
number = 4
words = 3

print (f'i bought {number} number and {words} words')
# Out:
# i bought 4 number and 3 words

# %%
city = "capital of india is delhi"
print(city)
# Out:
# capital of india is delhi

# %%
#

print ("AAAAAAAAAAAA")
print ("A"*12)
# Out:
# AAAAAAAAAAAA
# AAAAAAAAAAAA

# %%
# indentation
blo

# %%
#squre of a number
n = input("maximul number?") #Block 1
n = int(n)+1 #Block 2
print(n) #Block 1
squre = 0
for a range(0,n): #Block 1
 for b in range(a,n):

# %%
txt = 'python'
print(len(txt))

if len(txt)>10:
  print(txt)
else:
  print('no text')
# Out:
# 6
# no text

# %%
l1 = [3,7,2,9,12]

def function(x):
  for i in x:
    print(i+4)

function(l1)
# Out:
# 7
# 11
# 6
# 13
# 16

# %%
# While loop

lower = 10
upper = 20
num = 11
while((num < upper)&(num > lower)): # till the condition inside the while loop is true it stays in the loop
 num = num+1
print (num)
# Out:
# 20

# %%
#data types int,float,str

a = 10
type(a)
# Out:
# int

# %%
a = 10.0
type(a)
# Out:
# float

# %%
a = 10.67
print(a)
b = int(a) # type casting
print(b)
c = float(c)
print(c)
d = str(d)
print(d)

# %%
float(d)+1
