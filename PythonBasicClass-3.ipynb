# %%
'''
Block 1
<Tab

# %%
l1 = [2,3,4,5,6]


for i in l1: #Block1
 if(i-2==0):#Bloock2
  print(i)
else:
  print ('not a even')
# Out:
# 2
# not a even

# %%
l1 = ['prasanna','kiran','sohel','vinay']

for i in l1:
 if (i =='prasanna'):
  print(i)
 else:
  print('not my name')
# Out:
# prasanna
# not my name
# not my name
# not my name

# %%
l1 = [1,2,3,4,5,6]

for i in l1:
  if(i/2<1):
    print(i)
else:
  print('less then one')
# Out:
# 1
# less then one

# %%
'''
[1,2,3,'kiran','vivek','line']

'''
if(i == 'kiran'):
  print(i)
elif(i == 'vivek')
  print(i)
 else:

# %%
l1 = [1,2,3,'kiran','vivek','line']

for i in l1:

  if i == 'vivek':
    print(i)
  elif i == 'line':
    print (i)
  else:
    print ('number')
# Out:
# number
# number
# number
# number
# vivek
# line
