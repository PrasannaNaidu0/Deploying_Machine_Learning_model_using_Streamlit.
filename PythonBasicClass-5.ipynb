# %%
from os import X_OK
'''

create a list of 5 names and write a function to combine those

'''
l1 = ['Emma', 'Noah', 'Olivia', 'Liam', 'Ava']

def createsentence(names):
 str1 = ' '
for i in names:
 str1 = str1+i
print(names)

createsentence(l1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-c2c5f0548d26> in <cell line: 11>()
#      10  str1 = ' '
#      11 for i in names:
# ---> 12  str1 = str1+i
#      13 print(names)
#      14
#
# NameError: name 'str1' is not defined
